# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyansh-Bari/Sentiment-Analysis-using-RoBERTa/blob/main/Data_Cleaning_U_R_War_Tweets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the file
df = pd.read_csv('/content/tweets (5).csv')

# Preview the first few rows
df.head()
# Out:
#    Tweet_count                    Username  \
# 0            1                 Jay in Kyiv
# 1            2                     LuxAlgo
# 2            3                    ABC News
# 3            4  Anna_From_Ukraine_Official
# 4            5              Economic Times
#
#                                                 Text  \
# 0  Russia's war now entirely aimed at the civilia...
# 1  🚨 TRADE WAR UPDATE 🚨\n\n🇺🇸 President Trump sai...
# 2  President Donald Trump says he's unhappy with ...
# 3  🚨 Putin wants war, not peace. While negotiatin...
# 4  '#Putin will die soon…': #Zelenskyy’s shocking...
#
#                        Created At  Retweets  Likes
# 0  Fri Feb 21 10:11:30 +0000 2025      2678   6854
# 1  Sun Mar 30 19:27:46 +0000 2025         7     40
# 2  Mon Mar 31 19:17:07 +0000 2025        21     65
# 3  Sat Mar 29 21:02:58 +0000 2025       262    988
# 4  Thu Mar 27 16:35:00 +0000 2025         3      9

# %%
# !pip install unidecode
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 4.4 MB/s eta 0:00:00
# ...

# %%
import re
import string
import nltk
nltk.download('punkt_tab')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from html import unescape
from unidecode import unidecode

# Download required resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    text = text.lower()
    text = unescape(text)
    text = re.sub(r'http\S+', '', text)
    text = unidecode(text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub(r'\d+', '', text)
    tokens = nltk.word_tokenize(text)
    cleaned = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return ' '.join(cleaned)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Replace 'text' with the actual column name if different
df['cleaned_text'] = df['Text'].astype(str).apply(clean_text)

# Show a preview
df[['Text', 'cleaned_text']].head()
# Out:
#                                                 Text  \
# 0  Russia's war now entirely aimed at the civilia...
# 1  🚨 TRADE WAR UPDATE 🚨\n\n🇺🇸 President Trump sai...
# 2  President Donald Trump says he's unhappy with ...
# 3  🚨 Putin wants war, not peace. While negotiatin...
# 4  '#Putin will die soon…': #Zelenskyy’s shocking...
#
#                                         cleaned_text
# 0  russia war entirely aimed civilian population ...
# 1  trade war update president trump said today ru...
# 2  president donald trump say he unhappy russian ...
# 3  putin want war peace negotiating white house h...
# 4  putin die soon zelenskyys shocking prediction ...

# %%
# Save the cleaned file
df.to_csv('cleaned_tweets.csv', index=False)
